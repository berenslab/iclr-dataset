# %% [markdown]
# # Download the blind ICLR2025 data from OpenReview

# %%
# %matplotlib notebook

import numpy as np
import pandas as pd
import pylab as plt

import requests
import time

# %%
# %%time

# Download titles/abstracts/authors of all papers (this part is fast)

titles = []
abstracts = []
years = []
forum_ids = []
decisions = []
authors = []
keywords = []

for year in [2025]:
    print(year, end=': ')
    for query in ['submission', 'Submission', 'Blind_Submission', 
                  'Withdrawn_Submission', 'Rejected_Submission', 
                  'Desk_Rejected_Submission', '']:
        if year <= 2017:
            if query == '':
                continue
            url = f'https://api.openreview.net/notes?invitation=ICLR.cc%2F{year}%2Fconference%2F-%2F{query}'
        elif year <= 2023:
            if query == '':
                continue
            url = f'https://api.openreview.net/notes?invitation=ICLR.cc%2F{year}%2FConference%2F-%2F{query}'
        else:
            if query != '':
                query = '/' + query
            url = f'https://api2.openreview.net/notes?content.venueid=ICLR.cc/{year}/Conference{query}'        
            
        for offset in range(0, 10_000, 1000):
            df = pd.DataFrame(requests.get(url + f'&offset={offset}').json()['notes'])
            if len(df) > 0:
                print(len(df), end=' ')
                if year < 2024:
                    titles    += [d['title'].strip() for d in df['content'].values]
                    abstracts += [d['abstract'].strip() for d in df['content'].values]
                    keywords  += [d['keywords'] for d in df['content'].values]
                    authors   += [', '.join(d['authors']) for d in df['content']]
                else:
                    titles    += [d['title']['value'].strip() for d in df['content'].values]
                    abstracts += [d['abstract']['value'].strip() for d in df['content'].values]
                    keywords  += [d['keywords']['value'] for d in df['content'].values]
                    if 'authors' in df['content'].values[0]:
                        authors   += [', '.join(d['authors']['value']) for d in df['content'].values]
                    else:
                        authors += [''] * len(df)
                years     += [year] * len(df)
                forum_ids += list(df.forum)
                                                
                if 'Withdrawn_Submission' in query:
                    decisions += ['Withdrawn'] * len(df)
                elif 'Desk_Rejected_Submission' in query:
                    decisions += ['Desk rejected'] * len(df)
                elif 'Rejected_Submission' in query:
                    decisions += ['Reject'] * len(df)    
                else:
                    decisions += [''] * len(df)
            else:
                break
    print('')
print('')

print(f'Found {len(titles)} papers\n')
# Out:
# 2025: 1000 1000 1000 1000 1000 1000 1000 1000 1000 1000 67 14
#
# Found 10081 papers
#
# CPU times: user 1.66 s, sys: 153 ms, total: 1.82 s
# Wall time: 23.7 s

# %%
# Prepare the dataframe

iclr = pd.DataFrame.from_dict({
    'year': np.array(years).astype(int), 
    'id': forum_ids, 
    'title': titles, 
    'abstract': abstracts,
    'authors': authors,
    'decision': decisions,
    'scores': [[]] * len(abstracts),
    'keywords': [[kk.lower() for kk in k] for k in keywords],
})

# Kicking out nonsense abstracts

mask = np.array([len(a) >= 100 for a in iclr.abstract])

print(f'Removing {np.sum(~mask)} submissions with abstract length below 100 characters:')
for abstract in iclr[~mask]['abstract'].values:
    print('  ' + abstract)    
iclr = iclr[mask].reset_index(drop=True)
# Out:
# Removing 2 submissions with abstract length below 100 characters:
#   xx
#   xx

# %%
# Inspect

assert iclr.id.unique().size == len(iclr)

iclr
# Out:
#        year          id                                              title  \
# 0      2025  5sRnsubyAK  Neuroacoustic Patterns: Constant Q Cepstral Co...
# 1      2025  J1SGf2lyr6  A Feature-Aware Federated Learning Framework f...
# 2      2025  49ti6LOUw5  UnoLoRA: Single Low-Rank Adaptation for Effici...
# 3      2025  zkNCWtw2fd  Synergistic Approach for Simultaneous Optimiza...
# 4      2025  viQ1bLqKY0  EXecution-Eval: Can language models execute re...
# ...     ...         ...                                                ...
# 10074  2025  InxxTu0Bfs  GIFT-SW: Gaussian noise Injected Fine-Tuning o...
# 10075  2025  qXwVXj03nO  A collaborative Multi-Agent LLM Approach for K...
# 10076  2025  SY70rVSr3M  Model Mimic Attack: Knowledge Distillation for...
# 10077  2025  pjfvmZWFfX  EEE-Bench: A Comprehensive Multimodal Electric...
# 10078  2025  IpLXuqmP0C  DynMoLE: Boosting Mixture of LoRA Experts Fine...
#
#                                                 abstract  \
# 0      Early identification of neurodegenerative dise...
# 1      The expansion of 5G networks has led to remark...
# 2      Recent research has demonstrated the efficacy ...
# 3      Information retrieval across different languag...
# 4      As language models (LLMs) advance, traditional...
# ...                                                  ...
# 10074  Parameter Efficient Fine-Tuning (PEFT) methods...
# 10075  Retrieval-Augmented Generation (RAG) systems h...
# 10076  The vulnerability of artificial neural network...
# 10077  Recent studies on large language models (LLMs)...
# 10078  Instruction-based fine-tuning of large languag...
#
#                                                  authors       decision  \
# 0
# 1
# 2
# 3
# 4
# ...                                                  ...            ...
# 10074  Maxim Zhelnin, Viktor Moskvoretskii, Egor Shve...  Desk rejected
# 10075  Ankur Krishna, surya ardham, Chetan Malhotra, ...  Desk rejected
# 10076  Kirill Lukyanov, Andrew Perminov, Denis Turdak...  Desk rejected
# 10077  Ming Li, Jike Zhong, Tianle Chen, Konstantinos...  Desk rejected
# 10078  Dengchun Li, Naizheng Wang, Zihao Zhang, Haoya...  Desk rejected
#
#       scores                                           keywords
# 0         []  [neurodegenerative disorder, constant q cepstr...
# 1         []  [federated learning, anomaly detection, 5g net...
# 2         []                  [lora, multi-task learning, peft]
# 3         []  [information retrieval, multilingualism and cr...
# 4         []  [large language model, evaluation, benchmark, ...
# ...      ...                                                ...
# 10074     []  [large language models, parameter efficient fi...
# 10075     []  [large language models (llms), knowledge graph...
# 10076     []  [black-box adversarial attack, knowledge disti...
# 10077     []    [benchmark, evaluation, large multimodal model]
# 10078     []  [large language model, self-supervised fine-tu...
#
# [10079 rows x 8 columns]

# %%
# Combine and save

iclr24v2 = pd.read_parquet('../data/iclr24v2.parquet')

iclr25v1 = pd.concat((iclr24v2, iclr.sort_values(by='id'))).reset_index(drop=True)

iclr25v1.to_parquet('../data/iclr25v1.parquet')
