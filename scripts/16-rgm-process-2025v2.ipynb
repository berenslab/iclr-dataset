# %%
import pandas as pd
import random
import numpy as np
from random import randint

import torch
from transformers import AutoTokenizer, AutoModel
# import adapters
# from adapters import AutoAdapterModel
# from sentence_transformers import SentenceTransformer
import gc
# import cohere
from tqdm.notebook import tqdm
# import tiktoken
# from openai import OpenAI

import scipy as sp
from scipy import sparse
import sklearn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import normalize
from openTSNE import TSNE, affinity

import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import glasbey

import time
import pickle
import memory_profiler

# %load_ext memory_profiler

from pathlib import Path
import distro

# %load_ext watermark

# %%
# %load_ext autoreload
# %autoreload 2

import sys

sys.path.append(
    "/gpfs01/berens/user/rgonzalesmarquez/phd/iclr-dataset/scripts"
)  # MANUAL FIX TO PATH ISSUE FROM VSCODE

from embeddings import generate_embeddings
from plotting import plot_tsne_colors, plot_label_tags

# %%
import black
import jupyter_black

jupyter_black.load(line_length=79)

# %%
variables_path = Path("../results/variables/iclr25v2")
figures_path = Path("../results/figures")
data_path = Path("../data")

# %%
pwd
# Out:
# '/gpfs01/berens/user/rgonzalesmarquez'

# %%
# MANUAL FIX TO PATH ISSUE FROM VSCODE
nb_path = Path("phd/iclr-dataset/scripts")
assert nb_path.exists(), "The path does not exist"

variables_path = (nb_path / variables_path).resolve(strict=True)
figures_path = (nb_path / figures_path).resolve(strict=True)
data_path = (nb_path / data_path).resolve(strict=True)

# %%
plt.style.use((nb_path / Path("matplotlib_style.txt")).resolve(strict=True))

# %%
# %watermark -a 'Rita González-Márquez' -t -d -tz -u -v -iv -w -m -h -p transformers
print(distro.name(pretty=True))
# Out:
# Author: Rita González-Márquez
#
# Last updated: 2025-03-20 14:23:32CET
#
# Python implementation: CPython
# Python version       : 3.12.4
# IPython version      : 8.31.0
#
# transformers: 4.45.2
#
# Compiler    : GCC 11.2.0
# OS          : Linux
# Release     : 4.18.0-553.el8_10.x86_64
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 64
# Architecture: 64bit
#
# Hostname: rgonzalesmarquez_GPU0-llm_gber7
#
# torch          : 2.5.0
# scipy          : 1.11.4
# openTSNE       : 1.0.2
# jupyter_black  : 0.4.0
# seaborn        : 0.13.2
# tqdm           : 4.66.4
# sys            : 3.12.4 | packaged by Anaconda, Inc. | (main, Jun 18 2024, 15:12:24) [GCC 11.2.0]
# black          : 24.10.0
# glasbey        : 0.2.1
# pandas         : 2.2.3
# distro         : 1.9.0
# transformers   : 4.45.2
# memory_profiler: 0.61.0
# sklearn        : 1.5.2
# numpy          : 1.26.4
# matplotlib     : 3.9.2
#
# Watermark: 2.5.0
#
# Ubuntu 24.04 LTS

# %% [markdown]
# # Import

# %%
# %%time
iclr = pd.read_parquet(
    data_path / "iclr25v2.parquet",
    engine="pyarrow",
)
# Out:
# CPU times: user 248 ms, sys: 90.7 ms, total: 339 ms
# Wall time: 275 ms

# %%
iclr.keywords = iclr.keywords.transform(lambda x: list(x))
iclr.scores = iclr.scores.transform(lambda x: list(x))

# %%
iclr
# Out:
#        year          id                                              title  \
# 0      2017   B1-Hhnslg        Prototypical Networks for Few-shot Learning
# 1      2017   B1-q5Pqxl  Machine Comprehension Using Match-LSTM and Ans...
# 2      2017   B16Jem9xe             Learning in Implicit Generative Models
# 3      2017   B16dGcqlx                    Third Person Imitation Learning
# 4      2017   B184E5qee  Improving Neural Language Models with a Contin...
# ...     ...         ...                                                ...
# 34519  2025  zxO4WuVGns  Inverse decision-making using neural amortized...
# 34520  2025  zxbQLztmwb  Emergent Symbol-Like Number Variables in Artif...
# 34521  2025  zxqdVo9FjY  Generalization for Least Squares Regression wi...
# 34522  2025  zyGrziIVdE          Exploration by Running Away from the Past
# 34523  2025  zzR1Uskhj0  High Probability Bounds for Cross-Learning Con...
#
#                                                 abstract  \
# 0      A recent approach to few-shot classification c...
# 1      Machine comprehension of text is an important ...
# 2      Generative adversarial networks (GANs) provide...
# 3      Reinforcement learning (RL) makes it possible ...
# 4      We propose an extension to neural network lang...
# ...                                                  ...
# 34519  Bayesian observer and actor models have provid...
# 34520  There is an open question of what types of num...
# 34521  Random matrix theory has proven to be a valuab...
# 34522  The ability to explore efficiently and effecti...
# 34523  Motivated by applications in online bidding an...
#
#                                                  authors  \
# 0               Jake Snell, Kevin Swersky, Richard Zemel
# 1                              Shuohang Wang, Jing Jiang
# 2                Shakir Mohamed, Balaji Lakshminarayanan
# 3         Bradly C Stadie, Pieter Abbeel, Ilya Sutskever
# 4          Edouard Grave, Armand Joulin, Nicolas Usunier
# ...                                                  ...
# 34519  Dominik Straub, Tobias F. Niehues, Jan Peters,...
# 34520  Satchel Grant, Noah Goodman, James Lloyd McCle...
# 34521                         Jiping Li, Rishi Sonthalia
# 34522  Paul-Antoine LE TOLGUENEC, Yann Besse, Florent...
# 34523                      Ruiyuan Huang, Zengfeng Huang
#
#                        decision           scores  \
# 0                        Reject        [6, 4, 5]
# 1               Accept (Poster)        [6, 6, 7]
# 2      Invite to Workshop Track        [8, 7, 6]
# 3               Accept (Poster)        [6, 5, 6]
# 4               Accept (Poster)        [7, 9, 5]
# ...                         ...              ...
# 34519           Accept (Poster)        [6, 6, 6]
# 34520                    Reject     [3, 5, 6, 5]
# 34521                    Reject  [5, 3, 5, 5, 6]
# 34522                    Reject     [3, 3, 5, 3]
# 34523                    Reject  [5, 5, 8, 6, 6]
#
#                                                 keywords             labels
# 0                     [deep learning, transfer learning]  transfer learning
# 1           [natural language processing, deep learning]    language models
# 2                                [unsupervised learning]          unlabeled
# 3                                                     []          unlabeled
# 4                          [natural language processing]    language models
# ...                                                  ...                ...
# 34519  [Bayesian actor models, perception and action,...          unlabeled
# 34520  [mechanistic interpretability, numeric cogniti...          unlabeled
# 34521  [Generalization, Random Matrix Theory, Spiked ...          unlabeled
# 34522  [Reinforcement Learning, Exploration, Deep Lea...          unlabeled
# 34523  [contextual bandits, cross-learning, high-prob...          unlabeled
#
# [34524 rows x 9 columns]

# %%
labels_iclr = iclr.labels.to_numpy()
len(np.unique(labels_iclr))
# Out:
# 51

# %%
pickle_in = open(
    variables_path / "dict_label_to_color.pkl",
    "rb",
)
dict_label_to_color = pickle.load(pickle_in)

# %%
len(dict_label_to_color)
# Out:
# 51

# %%
colors_iclr = np.vectorize(dict_label_to_color.get)(labels_iclr)

# %% [markdown]
# # Obtain representation

# %% [markdown]
# ## SBERT

# %% [markdown]
# ### General pipeline

# %%
model_names = [
    "SBERT",
]

model_paths = [
    "sentence-transformers/all-mpnet-base-v2",
]
print(model_names)
# Out:
# ['SBERT']

# %%
# %%time
for i, model_name in enumerate(model_names):
    # set up model
    print("Model: ", model_name)

    random_state = random.seed(42)
    device = "cuda" if torch.cuda.is_available() else "cpu"
    print("Running on device: {}".format(device))

    tokenizer = AutoTokenizer.from_pretrained(model_paths[i])
    model = AutoModel.from_pretrained(model_paths[i])
    print(model_paths[i])

    model = model.to(device)

    # get embeddings
    embedding_cls, embedding_sep, embedding_av = generate_embeddings(
        iclr.abstract.to_list(), tokenizer, model, device, batch_size=256
    )

    # save embeddings
    saving_path = Path("embeddings_" + model_name.lower())
    (variables_path / saving_path).mkdir(exist_ok=True)

    np.save(
        variables_path / saving_path / "embedding_abstracts_only_cls",
        embedding_cls,
    )
    np.save(
        variables_path / saving_path / "embedding_abstracts_only_sep",
        embedding_sep,
    )
    np.save(
        variables_path / saving_path / "embedding_abstracts_only_av",
        embedding_av,
    )

    model = None
    gc.collect()
    torch.cuda.empty_cache()

    print("----------------------------")
# Out:
# Model:  SBERT
# Running on device: cuda
# sentence-transformers/all-mpnet-base-v2
#   0%|          | 0/135 [00:00<?, ?it/s]
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable
# ----------------------------
# CPU times: user 7min 3s, sys: 28.6 s, total: 7min 32s
# Wall time: 5min 17s

# %% [markdown]
# # t-SNE

# %%
# %%time
for i, model_name in enumerate(model_names):
    # import
    saving_path = Path("embeddings_" + model_name.lower())

    embedding_av = np.load(
        variables_path / saving_path / "embedding_abstracts_only_av.npy"
    )

    if model_name != "ST5":
        embedding_cls = np.load(
            variables_path / saving_path / "embedding_abstracts_only_cls.npy"
        )
        embedding_sep = np.load(
            variables_path / saving_path / "embedding_abstracts_only_sep.npy"
        )

        # t-SNE
        tsne_cls = TSNE(verbose=True, random_state=42).fit(embedding_cls)
        tsne_sep = TSNE(verbose=True, random_state=42).fit(embedding_sep)

    tsne_av = TSNE(verbose=True, random_state=42).fit(embedding_av)

    # save
    if model_name != "ST5":
        np.save(variables_path / saving_path / "tsne_cls.npy", tsne_cls)
        np.save(variables_path / saving_path / "tsne_sep.npy", tsne_sep)
    np.save(variables_path / saving_path / "tsne_av.npy", tsne_av)
# Out:
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 90 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 110.58 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 1.05 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.40 seconds
# ===> Running optimization with exaggeration=12.00, lr=2877.00 for 250 iterations...
# Iteration   50, KL divergence 6.1887, 50 iterations in 3.0884 sec
# Iteration  100, KL divergence 6.2566, 50 iterations in 3.0799 sec
# Iteration  150, KL divergence 6.2576, 50 iterations in 3.1669 sec
# Iteration  200, KL divergence 6.2570, 50 iterations in 3.0284 sec
# Iteration  250, KL divergence 6.2569, 50 iterations in 3.0414 sec
#    --> Time elapsed: 15.41 seconds
# ===> Running optimization with exaggeration=1.00, lr=34524.00 for 500 iterations...
# Iteration   50, KL divergence 3.2998, 50 iterations in 3.0959 sec
# Iteration  100, KL divergence 3.0195, 50 iterations in 3.8732 sec
# Iteration  150, KL divergence 2.8856, 50 iterations in 5.1553 sec
# Iteration  200, KL divergence 2.8032, 50 iterations in 6.1780 sec
# Iteration  250, KL divergence 2.7456, 50 iterations in 7.7805 sec
# Iteration  300, KL divergence 2.7017, 50 iterations in 8.4483 sec
# Iteration  350, KL divergence 2.6676, 50 iterations in 9.4526 sec
# Iteration  400, KL divergence 2.6401, 50 iterations in 10.4388 sec
# Iteration  450, KL divergence 2.6165, 50 iterations in 11.6804 sec
# Iteration  500, KL divergence 2.5970, 50 iterations in 13.0935 sec
#    --> Time elapsed: 79.20 seconds
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 90 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 110.74 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.97 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.48 seconds
# ===> Running optimization with exaggeration=12.00, lr=2877.00 for 250 iterations...
# Iteration   50, KL divergence 6.3929, 50 iterations in 3.1852 sec
# Iteration  100, KL divergence 6.3935, 50 iterations in 3.1199 sec
# Iteration  150, KL divergence 6.3952, 50 iterations in 3.1589 sec
# Iteration  200, KL divergence 6.3929, 50 iterations in 3.0724 sec
# Iteration  250, KL divergence 6.3935, 50 iterations in 3.0843 sec
#    --> Time elapsed: 15.62 seconds
# ===> Running optimization with exaggeration=1.00, lr=34524.00 for 500 iterations...
# Iteration   50, KL divergence 3.5382, 50 iterations in 3.0909 sec
# Iteration  100, KL divergence 3.2801, 50 iterations in 3.7502 sec
# Iteration  150, KL divergence 3.1597, 50 iterations in 4.7136 sec
# Iteration  200, KL divergence 3.0867, 50 iterations in 5.7868 sec
# Iteration  250, KL divergence 3.0349, 50 iterations in 6.6958 sec
# Iteration  300, KL divergence 2.9973, 50 iterations in 7.6579 sec
# Iteration  350, KL divergence 2.9666, 50 iterations in 8.4934 sec
# Iteration  400, KL divergence 2.9424, 50 iterations in 9.5681 sec
# Iteration  450, KL divergence 2.9228, 50 iterations in 10.0189 sec
# Iteration  500, KL divergence 2.9056, 50 iterations in 11.3397 sec
#    --> Time elapsed: 71.12 seconds
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 90 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 101.88 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 1.01 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.42 seconds
# ===> Running optimization with exaggeration=12.00, lr=2877.00 for 250 iterations...
# Iteration   50, KL divergence 6.0383, 50 iterations in 3.0214 sec
# Iteration  100, KL divergence 6.1200, 50 iterations in 2.9799 sec
# Iteration  150, KL divergence 6.1195, 50 iterations in 2.9850 sec
# Iteration  200, KL divergence 6.1203, 50 iterations in 2.9619 sec
# Iteration  250, KL divergence 6.1205, 50 iterations in 2.9745 sec
#    --> Time elapsed: 14.92 seconds
# ===> Running optimization with exaggeration=1.00, lr=34524.00 for 500 iterations...
# Iteration   50, KL divergence 3.2353, 50 iterations in 3.0587 sec
# Iteration  100, KL divergence 2.9737, 50 iterations in 3.9653 sec
# Iteration  150, KL divergence 2.8500, 50 iterations in 5.1614 sec
# Iteration  200, KL divergence 2.7712, 50 iterations in 6.2143 sec
# Iteration  250, KL divergence 2.7163, 50 iterations in 7.2464 sec
# Iteration  300, KL divergence 2.6735, 50 iterations in 8.3914 sec
# Iteration  350, KL divergence 2.6404, 50 iterations in 9.7603 sec
# Iteration  400, KL divergence 2.6141, 50 iterations in 10.6612 sec
# Iteration  450, KL divergence 2.5917, 50 iterations in 11.7372 sec
# Iteration  500, KL divergence 2.5728, 50 iterations in 13.3062 sec
#    --> Time elapsed: 79.50 seconds
# CPU times: user 10min 10s, sys: 38.4 s, total: 10min 49s
# Wall time: 10min 9s

# %%
tsne_av.shape
# Out:
# (34524, 2)

# %% [markdown]
# ## Plot

# %%
fig, ax = plt.subplots(figsize=(5, 3.2), dpi=300, layout="constrained")

xlim = (-95, 95)
ylim = (-95, 95)

model_name = "SBERT"
# load
saving_path = Path("embeddings_" + model_name.lower())
tsne_av = np.load(variables_path / saving_path / "tsne_av.npy")

plot_tsne_colors(
    tsne_av,
    colors_iclr,
    ax=ax,
    # plot_type="subplot_3",
)
plot_label_tags(
    tsne_av,
    colors_iclr,
    dict_label_to_color,
    x_lim=xlim,
    y_lim=(-120, 120),
    ax=ax,
    subset=False,
    fontsize=6,
    capitalize=False,
    middle_value=-10,
)

fig.savefig(figures_path / "tmp" / "tsne_embedding_sbert_iclr25v2_v1.png")
# Out:
# /gpfs01/berens/user/rgonzalesmarquez/phd/iclr-dataset/scripts/plotting.py:335: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ax.plot([x[i],center_cluster_coordinates_left.x[i]],[y[i],center_cluster_coordinates_left.y[i]], c=colr, linewidth=0.4, clip_on=False)
# /gpfs01/berens/user/rgonzalesmarquez/phd/iclr-dataset/scripts/plotting.py:351: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ax.plot([x[i],center_cluster_coordinates_right.x[i]],[y[i],center_cluster_coordinates_right.y[i]], c=colr, linewidth=0.4, clip_on=False)
