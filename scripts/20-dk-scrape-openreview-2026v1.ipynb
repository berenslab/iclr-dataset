# %% [markdown]
# # Download the blind ICLR2026 data from OpenReview

# %%
# %matplotlib notebook

import numpy as np
import pandas as pd
import pylab as plt

import requests
import time

# %%
# %%time

# Download titles/abstracts/authors of all papers (this part is fast)

titles = []
abstracts = []
years = []
forum_ids = []
decisions = []
authors = []
author_ids = []
keywords = []

for year in [2026]:
    print(year, end=': ')
    for query in ['submission', 'Submission', 'Blind_Submission', 
                  'Withdrawn_Submission', 'Rejected_Submission', 
                  'Desk_Rejected_Submission', '']:
        if year <= 2017:
            if query == '':
                continue
            url = f'https://api.openreview.net/notes?invitation=ICLR.cc%2F{year}%2Fconference%2F-%2F{query}'
        elif year <= 2023:
            if query == '':
                continue
            url = f'https://api.openreview.net/notes?invitation=ICLR.cc%2F{year}%2FConference%2F-%2F{query}'
        else:
            if query != '':
                query = '/' + query
            url = f'https://api2.openreview.net/notes?content.venueid=ICLR.cc/{year}/Conference{query}'        
            
        for offset in range(0, 20_000, 1000):
            json = requests.get(url + f'&offset={offset}').json()
            
            if 'name' in json and json['name'] == 'RateLimitError':
                time.sleep(30)
                json = requests.get(url + f'&offset={offset}').json()
                
            df = pd.DataFrame(json['notes'])
            if len(df) > 0:
                print(len(df), end=' ')
                if year < 2024:
                    titles    += [d['title'].strip() for d in df['content'].values]
                    abstracts += [d['abstract'].strip() for d in df['content'].values]
                    keywords  += [d['keywords'] for d in df['content'].values]
                    if year == 2017:
                        authors   += [', '.join(d['authors']) if isinstance(d['authors'], list)
                                      else d['authors'] for d in df['content']]
                        author_ids = [', '.join(d['authorids']) if 'authorids' in d 
                                      else d['author_emails'] for d in df['content']]
                    else:
                        authors   += [', '.join(d['authors']) for d in df['content']]
                        author_ids  += [', '.join(d['authorids']) for d in df['content']]
                else:
                    titles    += [d['title']['value'].strip() for d in df['content'].values]
                    abstracts += [d['abstract']['value'].strip() for d in df['content'].values]
                    keywords  += [d['keywords']['value'] for d in df['content'].values]
                    if 'authors' in df['content'].values[0]:
                        authors   += [', '.join(d['authors']['value']) for d in df['content'].values]
                        author_ids   += [', '.join(d['authorids']['value']) for d in df['content'].values]
                    else:
                        authors += [''] * len(df)
                        author_ids += [''] * len(df)
                years     += [year] * len(df)
                forum_ids += list(df.forum)
                                                
                if 'Withdrawn_Submission' in query:
                    decisions += ['Withdrawn'] * len(df)
                elif 'Desk_Rejected_Submission' in query:
                    decisions += ['Desk rejected'] * len(df)
                elif 'Rejected_Submission' in query:
                    decisions += ['Reject'] * len(df)    
                else:
                    decisions += [''] * len(df)
            else:
                break
    print('')
print('')

print(f'Found {len(titles)} papers\n')
# Out:
# 2026: 1000 1000 1000 1000 1000 1000 1000 1000 1000 1000 1000 1000 1000 1000 1000 1000 1000 1000 1000 674 123
#
# Found 19797 papers
#
# CPU times: user 2.97 s, sys: 213 ms, total: 3.18 s
# Wall time: 49.5 s

# %%
# Prepare the dataframe

# Split keyword strings with semicolons instead of commas
keywords = [
    [kk.strip() for kk in k[0].split(";") if kk.strip() != ''] 
    if len(k) > 0 and ";" in k[0] else k
    for k in keywords
]

# Remove trailing periods from keywords
keywords = [
    k[:-1] + [k[-1].strip()[:-1]]
    if len(k) > 0 and "." in k[-1].strip()[-1] else k
    for k in keywords
]

# Make sure all is lower-case
keywords = [[kk.lower() for kk in k] for k in keywords]

iclr = pd.DataFrame.from_dict({
    'year': np.array(years).astype(int), 
    'id': forum_ids, 
    'title': titles, 
    'abstract': abstracts,
    'authors': authors,
    'author_ids': author_ids,
    'decision': decisions,
    'scores': [[]] * len(abstracts),
    'keywords': keywords,
})

# Kicking out nonsense abstracts

mask = np.array([len(a) >= 100 for a in iclr.abstract])

print(f'Removing {np.sum(~mask)} submissions with abstract length below 100 characters:')
for abstract in iclr[~mask]['abstract'].values:
    print('  ' + abstract)    
iclr = iclr[mask].reset_index(drop=True)
# Out:
# Removing 4 submissions with abstract length below 100 characters:
#   This is a null submission.
#   1
#   Scaling Laws of Time Series: Performance Gains from Increasing Input Length
#   Video Gen

# %%
# Inspect

assert iclr.id.unique().size == len(iclr)

iclr
# Out:
#        year          id                                              title  \
# 0      2026  FPLNSx1jmL  Improving Developer Emotion Classification via...
# 1      2026  y5rLR9xZpn  Quantum-Inspired Image Encodings for Financial...
# 2      2026  kiVIVBmMTP  SAVIOR: Sample-efficient Alignment of Vision-L...
# 3      2026  IKJyRyHpHV  Revisiting Multilingual Data Mixtures in Langu...
# 4      2026  GGg2BmcBEp  One-Shot Style Personalization for RL Agents v...
# ...     ...         ...                                                ...
# 19788  2026  d7OM1LQp5t  Animer: Generating Editable Videos from Images...
# 19789  2026  WBys7MARr3  Damon: Dynamic model pruning for Dense Large L...
# 19790  2026  CmcHvBLAhE  Looking-back: Implicit Video Clips Re-focusing...
# 19791  2026  d5snaHpQm2  Incentivizing Visual Thinking Cues via Reinfor...
# 19792  2026  5HjayIPPjA  FlashEdit: Decoupling Speed, Structure, and Se...
#
#                                                 abstract  \
# 0      Detecting developer emotion in the informative...
# 1      This study proposes a quantum-inspired methodo...
# 2      Modern enterprises are increasingly adopting b...
# 3      The impact of different multilingual data mixt...
# 4      Reinforcement learning (RL) has achieved remar...
# ...                                                  ...
# 19788  Our method combines advanced computer vision t...
# 19789  With a vast number of parameters, Large Langua...
# 19790  Multimodal large language models (MLLMs) on vi...
# 19791  Modern vision-language models struggle with lo...
# 19792  Text-guided image editing with diffusion model...
#
#                                                  authors  \
# 0
# 1
# 2
# 3
# 4
# ...                                                  ...
# 19788  Junhao Chen, Gao Kejun, Xiang Li, Fangsheng We...
# 19789                             Jiateng Wei, Huan Wang
# 19790                                         Jinlong Li
# 19791                                         Jinlong Li
# 19792  Junyi Wu, Zhiteng Li, Haotong Qin, Xiaohong Li...
#
#                                               author_ids   decision scores  \
# 0                                                                       []
# 1                                                                       []
# 2                                                                       []
# 3                                                                       []
# 4                                                                       []
# ...                                                  ...        ...    ...
# 19788  ~Junhao_Chen2, ~Gao_Kejun1, ~Xiang_Li68, ~Fang...  Withdrawn     []
# 19789                         ~Jiateng_Wei1, ~Huan_Wang3  Withdrawn     []
# 19790                                       ~Jinlong_Li3  Withdrawn     []
# 19791                                       ~Jinlong_Li3  Withdrawn     []
# 19792  ~Junyi_Wu4, ~Zhiteng_Li2, ~Haotong_Qin1, ~Xiao...  Withdrawn     []
#
#                                                 keywords
# 0      [emotion detection, commit messages, software ...
# 1      [time-series classification, image encoding, q...
# 2      [finance, document processing, optical charact...
# 3      [multilingual llms, multilinguality, cross-lin...
# 4              [reinforcement learning, agent alignment]
# ...                                                  ...
# 19788                                 [video generation]
# 19789       [llms, structured pruning, dynamic sparsity]
# 19790         [mllm, reasoning, 3d, spatial, perception]
# 19791  [thinking, reinforcement, reasoning, planning,...
# 19792                                    [image editing]
#
# [19793 rows x 9 columns]

# %%
# Load iclr25v2 and clean keywords

iclr25v2 = pd.read_parquet('../data/iclr25v2.parquet')

keywords = iclr25v2.keywords.values

keywords = [list(k) for k in keywords]

print(len([k for k in keywords if len(k) > 0 and ";" in k[0]]))

# Split keyword strings with semicolons instead of commas
keywords = [
    [kk.strip() for kk in k[0].split(";") if kk.strip() != ''] 
    if len(k) > 0 and ";" in k[0] else k
    for k in keywords
]

# Remove trailing periods from keywords
keywords = [
    k[:-1] + [k[-1].strip()[:-1]]
    if len(k) > 0 and "." in k[-1].strip()[-1] else k
    for k in keywords
]

# Make sure all is lower-case
keywords = [[kk.lower() for kk in k] for k in keywords]

iclr25v2.keywords = keywords

iclr25v2
# Out:
# 1154
#        year          id                                              title  \
# 0      2017   B1-Hhnslg        Prototypical Networks for Few-shot Learning
# 1      2017   B1-q5Pqxl  Machine Comprehension Using Match-LSTM and Ans...
# 2      2017   B16Jem9xe             Learning in Implicit Generative Models
# 3      2017   B16dGcqlx                    Third Person Imitation Learning
# 4      2017   B184E5qee  Improving Neural Language Models with a Contin...
# ...     ...         ...                                                ...
# 36108  2025  zxg6601zoc  Re-Imagining Multimodal Instruction Tuning: A ...
# 36109  2025  zxqdVo9FjY  Generalization for Least Squares Regression wi...
# 36110  2025  zyGrziIVdE          Exploration by Running Away from the Past
# 36111  2025  zz9jAssrwL  Bayesian Policy Distillation via Offline RL fo...
# 36112  2025  zzR1Uskhj0  High Probability Bounds for Cross-Learning Con...
#
#                                                 abstract  \
# 0      A recent approach to few-shot classification c...
# 1      Machine comprehension of text is an important ...
# 2      Generative adversarial networks (GANs) provide...
# 3      Reinforcement learning (RL) makes it possible ...
# 4      We propose an extension to neural network lang...
# ...                                                  ...
# 36108  Multimodal instruction tuning has proven to be...
# 36109  Random matrix theory has proven to be a valuab...
# 36110  The ability to explore efficiently and effecti...
# 36111  High-performance deep reinforcement learning f...
# 36112  Motivated by applications in online bidding an...
#
#                                                  authors  \
# 0               Jake Snell, Kevin Swersky, Richard Zemel
# 1                              Shuohang Wang, Jing Jiang
# 2                Shakir Mohamed, Balaji Lakshminarayanan
# 3         Bradly C Stadie, Pieter Abbeel, Ilya Sutskever
# 4          Edouard Grave, Armand Joulin, Nicolas Usunier
# ...                                                  ...
# 36108  Yiyang Liu, James Chenhao Liang, Ruixiang Tang...
# 36109                         Jiping Li, Rishi Sonthalia
# 36110  Paul-Antoine LE TOLGUENEC, Yann Besse, Florent...
# 36111  Jangwon Kim, Yoonsu Jang, Jonghyeok Park, Yoon...
# 36112                      Ruiyuan Huang, Zengfeng Huang
#
#                                               author_ids  \
# 0
# 1
# 2
# 3
# 4
# ...                                                  ...
# 36108  ~Yiyang_Liu3, ~James_Chenhao_Liang1, ~Ruixiang...
# 36109                     ~Jiping_Li1, ~Rishi_Sonthalia1
# 36110  ~Paul-Antoine_LE_TOLGUENEC1, ~Yann_Besse2, ~Fl...
# 36111  ~Jangwon_Kim2, ~Yoonsu_Jang1, ~Jonghyeok_Park3...
# 36112                  ~Ruiyuan_Huang1, ~Zengfeng_Huang1
#
#                        decision           scores  \
# 0                        Reject        [6, 4, 5]
# 1               Accept (Poster)        [6, 6, 7]
# 2      Invite to Workshop Track        [8, 7, 6]
# 3               Accept (Poster)        [6, 5, 6]
# 4               Accept (Poster)        [7, 9, 5]
# ...                         ...              ...
# 36108           Accept (Poster)     [6, 6, 6, 5]
# 36109                    Reject  [5, 3, 5, 5, 6]
# 36110                    Reject     [3, 3, 5, 3]
# 36111                 Withdrawn        [3, 3, 6]
# 36112                    Reject  [5, 5, 8, 6, 6]
#
#                                                 keywords             labels
# 0                     [deep learning, transfer learning]  transfer learning
# 1           [natural language processing, deep learning]    language models
# 2                                [unsupervised learning]          unlabeled
# 3                                                     []          unlabeled
# 4                          [natural language processing]    language models
# ...                                                  ...                ...
# 36108  [representation tuning, large multimodal model...          unlabeled
# 36109  [generalization, random matrix theory, spiked ...          unlabeled
# 36110  [reinforcement learning, exploration, deep lea...                 RL
# 36111  [neural network compression, reinforcement lea...                 RL
# 36112  [contextual bandits, cross-learning, high-prob...          unlabeled
#
# [36113 rows x 10 columns]

# %%
# Combine and save

iclr25v2 = pd.read_parquet('../data/iclr25v2.parquet')

iclr26v1 = pd.concat((iclr25v2, iclr.sort_values(by='id'))).reset_index(drop=True)

iclr26v1.to_parquet('../data/iclr26v1.parquet')

iclr26v1
# Out:
#        year          id                                              title  \
# 0      2017   B1-Hhnslg        Prototypical Networks for Few-shot Learning
# 1      2017   B1-q5Pqxl  Machine Comprehension Using Match-LSTM and Ans...
# 2      2017   B16Jem9xe             Learning in Implicit Generative Models
# 3      2017   B16dGcqlx                    Third Person Imitation Learning
# 4      2017   B184E5qee  Improving Neural Language Models with a Contin...
# ...     ...         ...                                                ...
# 55901  2026  zz3El6hqbs  Learning activation functions with PCA on a se...
# 55902  2026  zzJTo7ujql  Phased DMD: Few-step Distribution Matching Dis...
# 55903  2026  zzTDulLys0  vAttention: Verified Sparse Attention via Samp...
# 55904  2026  zzTQISAGUp  Polychromic Objectives for Reinforcement Learning
# 55905  2026  zzo3Sy3NSX  Your Language Model Secretly Contains Personal...
#
#                                                 abstract  \
# 0      A recent approach to few-shot classification c...
# 1      Machine comprehension of text is an important ...
# 2      Generative adversarial networks (GANs) provide...
# 3      Reinforcement learning (RL) makes it possible ...
# 4      We propose an extension to neural network lang...
# ...                                                  ...
# 55901  This work explores a novel approach to learnin...
# 55902  Distribution Matching Distillation (DMD) disti...
# 55903  State-of-the-art sparse attention methods for ...
# 55904  Reinforcement learning fine-tuning (RLFT) is a...
# 55905  Large Language Models (LLMs) demonstrate remar...
#
#                                               authors author_ids  \
# 0            Jake Snell, Kevin Swersky, Richard Zemel
# 1                           Shuohang Wang, Jing Jiang
# 2             Shakir Mohamed, Balaji Lakshminarayanan
# 3      Bradly C Stadie, Pieter Abbeel, Ilya Sutskever
# 4       Edouard Grave, Armand Joulin, Nicolas Usunier
# ...                                               ...        ...
# 55901
# 55902
# 55903
# 55904
# 55905
#
#                        decision     scores  \
# 0                        Reject  [6, 4, 5]
# 1               Accept (Poster)  [6, 6, 7]
# 2      Invite to Workshop Track  [8, 7, 6]
# 3               Accept (Poster)  [6, 5, 6]
# 4               Accept (Poster)  [7, 9, 5]
# ...                         ...        ...
# 55901                                   []
# 55902                                   []
# 55903                                   []
# 55904                                   []
# 55905                                   []
#
#                                                 keywords             labels
# 0                     [deep learning, transfer learning]  transfer learning
# 1           [natural language processing, deep learning]    language models
# 2                                [unsupervised learning]          unlabeled
# 3                                                     []          unlabeled
# 4                          [natural language processing]    language models
# ...                                                  ...                ...
# 55901  [deep neural networks, activation function lea...                NaN
# 55902  [diffusion models, distribution matching, dist...                NaN
# 55903                                 [sparse attention]                NaN
# 55904              [reinforcement learning, exploration]                NaN
# 55905          [large language models, persona modeling]                NaN
#
# [55906 rows x 10 columns]

# %%
[np.sum(iclr26v1.year==y) for y in np.arange(2017, 2027)]
# Out:
# [489, 1012, 1569, 2593, 3009, 3422, 4955, 7401, 11663, 19793]

# %%
iclr = pd.read_parquet('../data/iclr26v1.parquet')

keys = ["3d reconstruction", "novel view synthesis", "nerf", "gaussian splatting",
        "speech synthesis", "text-to-speech", "speech recognition",
        "drug discovery", "molecule generation",
        "partial differential equations", "partial differential equation", 
        "dynamical system", "dynamical systems", "pdes", "pde"]

allkeys = np.concatenate([k for k in iclr.keywords.values])

for key in keys:
    print(f"{key:30}", np.sum(allkeys == key))
# Out:
# 3d reconstruction              121
# novel view synthesis           99
# nerf                           52
# gaussian splatting             106
# speech synthesis               42
# text-to-speech                 45
# speech recognition             54
# drug discovery                 91
# molecule generation            56
# partial differential equations 95
# partial differential equation  29
# dynamical system               38
# dynamical systems              141
# pdes                           45
# pde                            44
